# %%
import kagglehub, pandas as pd, os

# %%
path = kagglehub.dataset_download("eduardopalmieri/nba-player-stats-season-2425")
df = pd.read_csv(os.path.join(path, [f for f in os.listdir(path) if f.endswith('.csv')][0]))
df.to_csv("../../storage/raw/players_stats.csv", index=False)
