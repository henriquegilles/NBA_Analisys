# %%
# !pip install duckdb requests
# Out:
# ...
#   Using cached duckdb-1.3.2-cp313-cp313-win_amd64.whl.metadata (7.2 kB)
# ...
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# ...
# Using cached duckdb-1.3.2-cp313-cp313-win_amd64.whl (11.4 MB)
# ...
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.0 MB 6.7 MB/s eta 0:00:02
#    ------- -------------------------------- 2.1/11.0 MB 6.6 MB/s eta 0:00:02
#    ------------ --------------------------- 3.4/11.0 MB 6.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.5/11.0 MB 6.2 MB/s eta 0:00:02
#    -------------------- ------------------- 5.8/11.0 MB 6.0 MB/s eta 0:00:01
#    ------------------------- -------------- 7.1/11.0 MB 6.1 MB/s eta 0:00:01
#    ------------------------------ --------- 8.4/11.0 MB 6.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/11.0 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 6.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
# ...

# %%
pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.0 MB 4.7 MB/s eta 0:00:01
#    ------------------ --------------------- 1.8/4.0 MB 5.2 MB/s eta 0:00:01
#    -------------------------- ------------- 2.6/4.0 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  3.9/4.0 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 5.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
